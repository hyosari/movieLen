# %%
import pandas as pd
import numpy as np

# %%
#file load movies.csv, ratings.csv,tags.csv

# %%
ratings = pd.read_csv("ml-latest-small/ratings.csv",sep=",",encoding="UTF-8")
movies = pd.read_csv("ml-latest-small/movies.csv",sep=",",encoding="UTF-8")
tags = pd.read_csv("ml-latest-small/tags.csv",sep=",",encoding="UTF-8")

# %%
movies.info()
ratings.info()
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9125 entries, 0 to 9124
# Data columns (total 3 columns):
# movieId    9125 non-null int64
# title      9125 non-null object
# genres     9125 non-null object
# dtypes: int64(1), object(2)
# memory usage: 213.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100004 entries, 0 to 100003
# Data columns (total 4 columns):
# userId       100004 non-null int64
# movieId      100004 non-null int64
# rating       100004 non-null float64
# timestamp    100004 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 4 columns):
# userId       1296 non-null int64
# movieId      1296 non-null int64
# tag          1296 non-null object
# timestamp    1296 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 40.6+ KB

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
lens=pd.merge(users,movies)

# %%
#the number of rating in each movie

# %%
lens.title.value_counts()[:25]
#Same instruction => lens.groupby("title").size().sort_values(ascending=False)[:25]
# Out:
# Forrest Gump (1994)                                                               341
# Pulp Fiction (1994)                                                               324
# Shawshank Redemption, The (1994)                                                  311
# Silence of the Lambs, The (1991)                                                  304
# Star Wars: Episode IV - A New Hope (1977)                                         291
# Jurassic Park (1993)                                                              274
# Matrix, The (1999)                                                                259
# Toy Story (1995)                                                                  247
# Schindler's List (1993)                                                           244
# Terminator 2: Judgment Day (1991)                                                 237
# Star Wars: Episode V - The Empire Strikes Back (1980)                             234
# ...

# %%
#agg function?

# %%
movie_stats=lens.groupby("title").agg({'rating': [np.size,np.mean]})

# %%
movie_stats.sort_values([('rating','mean')],ascending=False).head(5)
# Out:
#                                                    rating
#                                                      size mean
# title
# Ivan Vasilievich: Back to the Future (Ivan Vasi...    1.0  5.0
# Alien Escape (1995)                                   1.0  5.0
# Boiling Point (1993)                                  1.0  5.0
# Bone Tomahawk (2015)                                  1.0  5.0
# Borgman (2013)                                        1.0  5.0

# %%
#size at least 100

# %%
atleast_100 = movie_stats['rating']['size']>100
movie_stats[atleast_100].sort_values([('rating','mean')],ascending=False).head(15)
# Out:
#                                                    rating
#                                                      size      mean
# title
# Godfather, The (1972)                               200.0  4.487500
# Shawshank Redemption, The (1994)                    311.0  4.487138
# Godfather: Part II, The (1974)                      135.0  4.385185
# Usual Suspects, The (1995)                          201.0  4.370647
# Schindler's List (1993)                             244.0  4.303279
# One Flew Over the Cuckoo's Nest (1975)              144.0  4.256944
# Fargo (1996)                                        224.0  4.256696
# Pulp Fiction (1994)                                 324.0  4.256173
# American Beauty (1999)                              220.0  4.236364
# Dark Knight, The (2008)                             121.0  4.235537
# Casablanca (1942)                                   117.0  4.235043
# Star Wars: Episode V - The Empire Strikes Back ...  234.0  4.232906
# ...

# %%
# size atlest 150

# %%
movie_top50 = lens.groupby('title').agg({'rating': [np.size,np.mean]})

# %%
atleast_150=movie_top50['rating']['size']>150
movie_top50[atleast_150].sort_values([('rating','mean')],ascending=False).head(50)
# Out:
#                                                    rating
#                                                      size      mean
# title
# Godfather, The (1972)                               200.0  4.487500
# Shawshank Redemption, The (1994)                    311.0  4.487138
# Usual Suspects, The (1995)                          201.0  4.370647
# Schindler's List (1993)                             244.0  4.303279
# Fargo (1996)                                        224.0  4.256696
# Pulp Fiction (1994)                                 324.0  4.256173
# American Beauty (1999)                              220.0  4.236364
# Star Wars: Episode V - The Empire Strikes Back ...  234.0  4.232906
# Star Wars: Episode IV - A New Hope (1977)           291.0  4.221649
# Princess Bride, The (1987)                          163.0  4.208589
# Raiders of the Lost Ark (Indiana Jones and the ...  220.0  4.193182
# Matrix, The (1999)                                  259.0  4.183398
# ...
